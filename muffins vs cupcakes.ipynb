# %%
import numpy as np
import pandas as pd

from sklearn import svm

import matplotlib.pyplot as plt
import seaborn as sns; sns.set(font_scale=1.2)

# %matplotlib inline

# %%
recipes = pd.read_csv('Cupcakes vs Muffins.csv')
print(recipes.head())
# Out:
#      Type  Flour  Milk  Sugar  Butter  Egg  Baking Powder  Vanilla  Salt
# 0  Muffin     55    28      3       7    5              2        0     0
# 1  Muffin     47    24     12       6    9              1        0     0
# 2  Muffin     47    23     18       6    4              1        0     0
# 3  Muffin     45    11     17      17    8              1        0     0
# 4  Muffin     50    25     12       6    5              2        1     0

# %%
sns.lmplot('Flour', 'Sugar', data=recipes, hue='Type',
          palette='Set1', fit_reg=False, scatter_kws={"s": 70});
# Out:
# C:\Users\mintu chaudhary\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.lmplot('Flour', 'Sugar', data=recipes, hue='Type',
          palette='Set1', fit_reg=False, scatter_kws={"s": 70});
# Out:
# C:\Users\mintu chaudhary\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
type_label = np.where(recipes['Type']=='Muffin', 0, 1)
recipe_features = recipes.columns.values[1:].tolist()
recipe_features
ingredients = recipes[['Flour','Sugar']].values
print(ingredients)
# Out:
# [[55  3]
#  [47 12]
#  [47 18]
#  [45 17]
#  [50 12]
#  [55  3]
#  [54  7]
#  [47 10]
#  [50 17]
#  [50 17]
#  [39 26]
#  [42 16]
#  [34 20]
#  [39 17]
#  [38 23]
#  [42 26]
#  [36 21]
#  [38 31]
#  [36 24]
#  [34 23]]

# %%
type_label = np.where(recipes['Type']=='Muffin', 0, 1)
recipe_features = recipes.columns.values[1:].tolist()
recipe_features
ingredients = recipes[recipe_features].values
print(ingredients)
# Out:
# [[55 28  3  7  5  2  0  0]
#  [47 24 12  6  9  1  0  0]
#  [47 23 18  6  4  1  0  0]
#  [45 11 17 17  8  1  0  0]
#  [50 25 12  6  5  2  1  0]
#  [55 27  3  7  5  2  1  0]
#  [54 27  7  5  5  2  0  0]
#  [47 26 10 10  4  1  0  0]
#  [50 17 17  8  6  1  0  0]
#  [50 17 17 11  4  1  0  0]
#  [39  0 26 19 14  1  1  0]
#  [42 21 16 10  8  3  0  0]
#  [34 17 20 20  5  2  1  0]
#  [39 13 17 19 10  1  1  0]
#  [38 15 23 15  8  0  1  0]
#  [42 18 26  9  5  1  0  0]
#  [36 14 21 14 11  2  1  0]
#  [38 15 31  8  6  1  1  0]
#  [36 16 24 12  9  1  1  0]
#  [34 17 23 11 13  0  1  0]]

# %%
model = svm.SVC(kernel='linear')
model.fit(ingredients, type_label)
# Out:
# SVC(kernel='linear')

# %%
w = model.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(30, 60)
yy = a * xx - (model.intercept_[0]) / w[1]

b = model.support_vectors_[0]
yy_down = a * xx + (b[1] - a * b[0])
b = model.support_vectors_[-1]
yy_up = a * xx + (b[1] - a * b[0])

# %%
sns.lmplot('Flour', 'Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=False, scatter_kws={"s": 70});
plt.plot(xx, yy, linewidth=2, color='black')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')
# Out:
# C:\Users\mintu chaudhary\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
type_label = np.where(recipes['Type']=='Muffin', 0, 1)
recipe_features = recipes.columns.values[1:].tolist()
recipe_features
ingredients = recipes[['Flour','Sugar']].values
print(ingredients)
# Out:
# [[55  3]
#  [47 12]
#  [47 18]
#  [45 17]
#  [50 12]
#  [55  3]
#  [54  7]
#  [47 10]
#  [50 17]
#  [50 17]
#  [39 26]
#  [42 16]
#  [34 20]
#  [39 17]
#  [38 23]
#  [42 26]
#  [36 21]
#  [38 31]
#  [36 24]
#  [34 23]]

# %%
model = svm.SVC(kernel='linear')
model.fit(ingredients, type_label)
# Out:
# SVC(kernel='linear')

# %%
w = model.coef_[0]
a = -w[0] / w[1]
xx = np.linspace(30, 60)
yy = a * xx - (model.intercept_[0]) / w[1]

b = model.support_vectors_[0]
yy_down = a * xx + (b[1] - a * b[0])
b = model.support_vectors_[-1]
yy_up = a * xx + (b[1] - a * b[0])

# %%
sns.lmplot('Flour', 'Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=False, scatter_kws={"s": 70});
plt.plot(xx, yy, linewidth=2, color='black')
plt.plot(xx, yy_down, 'k--')
plt.plot(xx, yy_up, 'k--')
# Out:
# C:\Users\mintu chaudhary\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def muffin_or_cupcake(flour, sugar):
    if(model.predict([[flour, sugar]]))==0:
        print('You\'re looking at a muffin recipe!')
    else:
        print('You\'re looking at a cupcake recipe!')
        
muffin_or_cupcake(50,20)
# Out:
# You're looking at a muffin recipe!

# %%
sns.lmplot('Flour', 'Sugar', data=recipes, hue='Type', palette='Set1', fit_reg=False, scatter_kws={"s": 70});
plt.plot(xx, yy, linewidth=2, color='black')
plt.plot(50, 20,'yo', markersize='9')
# Out:
# C:\Users\mintu chaudhary\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
muffin_or_cupcake(40,20)
# Out:
# You're looking at a cupcake recipe!

# %%
muffin_or_cupcake(50,10)
# Out:
# You're looking at a muffin recipe!

# %%
muffin_or_cupcake(44,20)
# Out:
# You're looking at a muffin recipe!

# %%
muffin_or_cupcake(42,20)
# Out:
# You're looking at a cupcake recipe!

# %%
muffin_or_cupcake(43,20)
# Out:
# You're looking at a cupcake recipe!

# %%
muffin_or_cupcake(50,100)
# Out:
# You're looking at a muffin recipe!

# %%
muffin_or_cupcake(40,100)
# Out:
# You're looking at a cupcake recipe!
